# %% [markdown]
# # Criado por: Gabriel dos Santos, Hugo Botelho Santana, João Victor Gomes Macedo e Caíque Santos Santana

# %% [markdown]
# # Projeto: Predição de Insuficiência Cardíaca (Heart Failure Prediction Dataset)
#
# ## Objetivos:
# O objetivo desse prejeto é realizar a construção de um modelo que faça a predição de insuficiência cardíaca de pacientes, utilizando modelos preditivos aplicados ao dataset 'Heart Failure Prediction Dataset' do Kaggle. O projeto envolve desde a análise exploratória dos dados até a validação do modelo. O dataset apresenta as seguinte colunas:
#
# *   **Age:** Idade do paciente [anos].
#
# *   **Sex:** Sexo do paciente [M: Masculino, F: Feminino].
#
# *   **ChestPainType:** Tipo de dor no peito [TA: Angina Típica, ATA: Angina Atípica, NAP: Dor Não Anginal, ASY: Assintomático].
#
# *   **RestingBP:** Pressão arterial em repouso [mm Hg].
#
# *  **Cholesterol:** Colesterol sérico [mm/dl].
#
# *   **FastingBS:** Glicemia em jejum [1: se Glicemia em jejum > 120 mg/dl, 0: caso contrário].
#
# *   **RestingECG:** Resultados do eletrocardiograma em repouso [Normal: Normal, ST: anormalidade na onda ST-T (inversões da onda T e/ou elevação ou depressão do segmento ST > 0,05 mV), LVH: hipertrofia ventricular esquerda provável ou definitiva pelos critérios de 'Estes'].
#
# *   **MaxHR:** Frequência cardíaca máxima alcançada [Valor numérico entre 60 e 202].
#
# *   **ExerciseAngina:** Angina induzida por exercício [Y: Sim, N: Não].
#
# *   **Oldpeak:** Oldpeak = ST [Valor numérico medido em depressão].
#
# *   **ST_Slope:** Inclinação do segmento ST no pico do exercício [Up: ascendente, Flat: plano, Down: descendente].
#
# *   **HeartDisease:** Target [1: doença cardíaca, 0: Normal].

# %% [markdown]
# # Importando o Dataset e Bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

sns.set_style("darkgrid")
plt.rcParams["figure.figsize"] = (12, 7)

df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# ### Análise Geral

# %%
df.shape
# Out:
# (918, 12)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# Observe que alguns valores são incoerentes com a realidade, como: RestingBP, Cholesterol, Oldpeak, FastingBS. Sendo alguns zerados ou até negativos como no caso do Oldpeak. Outra observação é que existe uma diferença muito grande entre os valores máximos e 75% do Oldpeak, indicando um possível Outlier.

# %%
df.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
cp = sns.countplot(data=df, x='HeartDisease', hue='HeartDisease', palette='magma')

for container in cp.containers:
    cp.bar_label(container)
plt.title('Distribuição do target')
plt.show()

# %% [markdown]
# *Obs:* É um dataset balanceado.

# %%
df.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
matriz_corr = df.corr(numeric_only=True)
sns.heatmap(matriz_corr, annot=True, fmt='.2f')
plt.title('Matriz de Correlação')
plt.show()

# %%
numeric_column = df.select_dtypes(include=['number']).drop('HeartDisease', axis=1)

grafico_dispersao = px.scatter_matrix(df, dimensions=numeric_column, color='HeartDisease', height=800)
grafico_dispersao.show()

# %%
restingBp_invalido = (df['RestingBP'] == 0).sum()
cholesterol_invalido = (df['Cholesterol'] == 0).sum()
oldpeak_invalido = (df['Oldpeak'] < 0).sum()

print(f'A quantidade valores invalidos do restingBp é igual a: {restingBp_invalido}')
print(f'A quantidade valores invalidos do cholesterol é igual a: {cholesterol_invalido}')
print(f'A quantidade valores invalidos do oldpeak é igual a: {oldpeak_invalido}')
# Out:
# A quantidade valores invalidos do restingBp é igual a: 1
# A quantidade valores invalidos do cholesterol é igual a: 172
# A quantidade valores invalidos do oldpeak é igual a: 13

# %% [markdown]
# Como os valores de colesterol são maiores que 5% do dataset, então é interessante não dropar esses dados, e sim substituir pela mediana. No entanto, vale dropar os dados inválidos de restingbp e oldpeak, pois são menos que 5%.

# %% [markdown]
# ### Análise Univariada

# %% [markdown]
# #### Age

# %%
plt.figure(figsize=(15, 5))

# Histograma
plt.subplot(1, 2, 1)
sns.histplot(data = df, x = 'Age', kde=True, bins=30, hue='HeartDisease')
plt.title('Histograma de Age')
plt.xlabel('Age')
plt.ylabel('Frequência')

# Box Plot
plt.subplot(1, 2, 2)
sns.barplot(x=df['Age'])
plt.title(f'Box Plot de Age')
plt.xlabel('Age')

plt.tight_layout()

# %% [markdown]
# #### RestingBP

# %%
plt.figure(figsize=(15, 5))

# Histograma
plt.subplot(1, 2, 1)
sns.histplot(data = df, x = 'RestingBP', kde=True, bins=30, hue='HeartDisease')
plt.title('Histograma de RestingBP')
plt.xlabel('RestingBP')
plt.ylabel('Frequência')

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['RestingBP'])
plt.title(f'Box Plot de RestingBP')
plt.xlabel('RestingBP')

plt.tight_layout()

# %% [markdown]
# #### Cholesterol

# %%
plt.figure(figsize=(15, 5))

# Histograma
plt.subplot(1, 2, 1)
sns.histplot(data = df, x = 'Cholesterol', kde=True, bins=30, hue='HeartDisease')
plt.title('Histograma de Cholesterol')
plt.xlabel('Cholesterol')
plt.ylabel('Frequência')

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['Cholesterol'])
plt.title(f'Box Plot de Cholesterol')
plt.xlabel('Cholesterol')

plt.tight_layout()

# %% [markdown]
# #### MaxHR

# %%
plt.figure(figsize=(15, 5))

# Histograma
plt.subplot(1, 2, 1)
sns.histplot(data = df, x = 'MaxHR', kde=True, bins=30, hue='HeartDisease')
plt.title('Histograma de MaxHR')
plt.xlabel('MaxHR')
plt.ylabel('Frequência')

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['MaxHR'])
plt.title(f'Box Plot de MaxHR')
plt.xlabel('MaxHR')

plt.tight_layout()

# %% [markdown]
# #### Oldpeak

# %%
plt.figure(figsize=(15, 5))

# Histograma
plt.subplot(1, 2, 1)
sns.histplot(data = df, x = 'Oldpeak', kde=True, bins=30, hue='HeartDisease')
plt.title('Histograma de Oldpeak')
plt.xlabel('Oldpeak')
plt.ylabel('Frequência')

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['Oldpeak'])
plt.title(f'Box Plot de Oldpeak')
plt.xlabel('Oldpeak')

plt.tight_layout()

# %% [markdown]
# ### Distribuição das variáveis categóricas

# %%
categoricas = df.select_dtypes(include=['object']).columns.tolist()
categoricas.extend(['FastingBS'])

print(categoricas)
# Out:
# ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'FastingBS']

# %%
for coluna in categoricas:
    plt.figure(figsize=(10, 6))
    ax = sns.countplot(data=df, x=coluna, order=df[coluna].value_counts().index, palette='magma', hue='HeartDisease')
    plt.title(f'Distribuição de {coluna}')
    plt.xlabel(coluna)
    plt.ylabel('Número de registros')
    # Adicionar contagens nas barras
    for container in ax.containers:
        ax.bar_label(container)
    # plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

# %% [markdown]
# # Tratando Outliers e Valores Inválidos

# %%
dfClean = df.copy()
dfClean['cholesterol_invalido'] = (dfClean['Cholesterol'] == 0)
dfClean['oldpeak_invalido'] = (dfClean['Oldpeak'] < 0)
dfClean['restingBp_invalido'] = (dfClean['RestingBP'] == 0)

dfClean.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  cholesterol_invalido  \
# 0              N      0.0       Up             0                 False
# 1              N      1.0     Flat             1                 False
# 2              N      0.0       Up             0                 False
# 3              Y      1.5     Flat             1                 False
# 4              N      0.0       Up             0                 False
#
#    oldpeak_invalido  restingBp_invalido
# ...

# %%
dfClean.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
cholesterol_median = dfClean.loc[dfClean['cholesterol_invalido'] == False, 'Cholesterol'].median()
oldpeak_median = dfClean.loc[dfClean['oldpeak_invalido'] == False, 'Oldpeak'].median()
restingBp_median = dfClean.loc[dfClean['restingBp_invalido'] == False, 'RestingBP'].median()

dfClean.loc[dfClean['cholesterol_invalido'] == True, 'Cholesterol'] = cholesterol_median
dfClean.loc[dfClean['oldpeak_invalido'] == True, 'Oldpeak'] = oldpeak_median
dfClean.loc[dfClean['restingBp_invalido'] == True, 'RestingBP'] = restingBp_median

# %%
dfClean.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.538126   243.204793    0.233115  136.809368
# std      9.432617   17.990127    53.401297    0.423046   25.460334
# min     28.000000   80.000000    85.000000    0.000000   60.000000
# 25%     47.000000  120.000000   214.000000    0.000000  120.000000
# 50%     54.000000  130.000000   237.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.909804      0.553377
# std      1.040160      0.497414
# min      0.000000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
corr = dfClean.corr(numeric_only=True)
plt.figure(figsize= (15,6))
sns.heatmap(corr, annot=True, fmt='.2f')
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# # Pré-Processamento

# %% [markdown]
# ### Divisão entre Classe e Previsores

# %%
X_data = dfClean.drop('HeartDisease', axis=1)
Y_data = dfClean['HeartDisease']

# %%
X_data.shape
# Out:
# (918, 14)

# %%
Y_data.shape
# Out:
# (918,)

# %% [markdown]
# #### Usando One Hot Encoder para lidar com variáveis categóricas

# %%
categoric_columns = dfClean.select_dtypes(include='object').columns.tolist()
X_data = pd.get_dummies(X_data, columns=categoric_columns, drop_first=True)
X_data.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  \
# 0   40        140          289          0    172      0.0
# 1   49        160          180          0    156      1.0
# 2   37        130          283          0     98      0.0
# 3   48        138          214          0    108      1.5
# 4   54        150          195          0    122      0.0
#
#    cholesterol_invalido  oldpeak_invalido  restingBp_invalido  Sex_M  \
# 0                 False             False               False   True
# 1                 False             False               False  False
# 2                 False             False               False   True
# 3                 False             False               False  False
# 4                 False             False               False   True
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  \
# 0               True              False             False               True
# ...

# %% [markdown]
# #### Escalonamento

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
numeric_columns = X_data.select_dtypes(include='number').columns.tolist()
numeric_columns.remove('FastingBS')
print(numeric_columns)
# Out:
# ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

# %%
X_data.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  \
# 0   40        140          289          0    172      0.0
# 1   49        160          180          0    156      1.0
# 2   37        130          283          0     98      0.0
# 3   48        138          214          0    108      1.5
# 4   54        150          195          0    122      0.0
#
#    cholesterol_invalido  oldpeak_invalido  restingBp_invalido  Sex_M  \
# 0                 False             False               False   True
# 1                 False             False               False  False
# 2                 False             False               False   True
# 3                 False             False               False  False
# 4                 False             False               False   True
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  \
# 0               True              False             False               True
# ...

# %%
X_data[numeric_columns] = scaler.fit_transform(X_data[numeric_columns])
X_data.head()
# Out:
#         Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# 0 -1.433140   0.415002     0.858035          0  1.382928 -0.875154
# 1 -0.478484   1.527329    -1.184227          0  0.754157  0.086761
# 2 -1.751359  -0.141161     0.745617          0 -1.525138 -0.875154
# 3 -0.584556   0.303769    -0.547191          0 -1.132156  0.567718
# 4  0.051881   0.971166    -0.903182          0 -0.581981 -0.875154
#
#    cholesterol_invalido  oldpeak_invalido  restingBp_invalido  Sex_M  \
# 0                 False             False               False   True
# 1                 False             False               False  False
# 2                 False             False               False   True
# 3                 False             False               False  False
# 4                 False             False               False   True
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  \
# ...

# %% [markdown]
# #### Divisão entre teste e treino

# %%
from sklearn.model_selection import train_test_split

X_train, X_teste, Y_train, Y_teste = train_test_split(X_data, Y_data, test_size=0.15, random_state=42, stratify=Y_data)

X_train = X_train.to_numpy(dtype = np.float32)
X_teste = X_teste.to_numpy(dtype = np.float32)
Y_train = Y_train.to_numpy(dtype = np.float32)

# %%
X_train.shape
# Out:
# (780, 18)

# %%
X_teste.shape
# Out:
# (138, 18)

# %% [markdown]
# #### Adicionando 3° Dimensão para usar no LSTM

# %%
X_train = np.expand_dims(X_train, axis=1)
X_train.shape
# Out:
# (780, 1, 18)

# %%
X_teste = np.expand_dims(X_teste, axis=1)
X_teste.shape
# Out:
# (138, 1, 18)

# %%
X_data = np.expand_dims(X_data, axis=1)
X_data.shape
# Out:
# (918, 1, 18)

# %% [markdown]
# # Criação da Rede Neural LSTM

# %% [markdown]
# #### Criação do modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow as tf


def construirModelo(time_steps=10, qtdNeuroniosLSTM=32, qtdNeuroniosDense=64, dropout=0.3, learningRate=0.003, loss='mean_squared_error', optimizer='Adam',      
                    **kwargs):
    model = Sequential([
    LSTM(qtdNeuroniosLSTM, input_shape=(time_steps, X_data.shape[2])),
    Dropout(dropout),
    Dense(qtdNeuroniosDense, activation='relu'),
    Dense(qtdNeuroniosDense, activation='relu'),
    Dropout(dropout),
    Dense(qtdNeuroniosDense, activation='relu'),
    Dense(qtdNeuroniosDense, activation='relu'),
    Dropout(dropout),
    Dense(16, activation='sigmoid'),
    Dense(1, activation='sigmoid')
    ])
        
    if optimizer == 'Adam':
        optimizerModel = tf.keras.optimizers.Adam(learning_rate = learningRate)
    else:
        optimizerModel = tf.keras.optimizers.RMSprop(learning_rate = learningRate)

    model.compile(
    loss = loss,
    optimizer = optimizerModel,
    metrics = ['recall', 'accuracy']
    )

    return model
# Out:
# 2025-11-22 20:30:23.508118: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### Cross Validation do Modelo

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score 
from scikeras.wrappers import KerasClassifier

crossModel = KerasClassifier(model=construirModelo, epochs=30, batch_size=15, verbose=0)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(crossModel, X_data, Y_data, cv=kf, scoring='recall')

print(scores)
print("Média:", np.mean(scores))
# Out:
# /home/jvgmacedo/UESB CC/Machine Learning/Projeto/Heart-Failure-Prediction/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /home/jvgmacedo/UESB CC/Machine Learning/Projeto/Heart-Failure-Prediction/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /home/jvgmacedo/UESB CC/Machine Learning/Projeto/Heart-Failure-Prediction/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...

# %% [markdown]
# # Tunagem de Hiper Parâmetro

# %% [markdown]
# #### Utilizando o Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# TIME_STEPS=10, qtdNeuroniosLSTM=32, qtdNeuroniosDense=64, dropout=0.3, learningRate=0.003, loss='mean_squared_error', optimizer='Adam'

param_grid = { # Lista / Dicionário de possíveis hiperparâmetros do modelo
    'model__time_steps': [10, 20],
    'model__qtdNeuroniosLSTM': [32, 64, 128],
    'model__qtdNeuroniosDense': [32, 64, 128],
    'model__dropout': [0.2, 0.3],
    'model__learningRate': [0.001, 0.0001, 0.002],
    'model__loss': ['mean_squared_error', 'binary_crossentropy'],
    'model__optimizer': ['Adam', 'rmsprop'],
    'epochs': [10, 20],
    'batch_size': [15, 30]
}


grid = GridSearchCV(estimator=crossModel, param_grid=param_grid, cv=3, scoring='f1', n_jobs=-1)
grid.fit(X_train, Y_train)

Tunned_GB = grid.best_estimator_
y_predict = Tunned_GB.predict(X_teste)

print("Melhores parâmetros:", grid.best_params_)
print("Melhor F1-score na validação cruzada:", grid.best_score_)
# Out:
# /home/jvgmacedo/UESB CC/Machine Learning/Projeto/Heart-Failure-Prediction/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /home/jvgmacedo/UESB CC/Machine Learning/Projeto/Heart-Failure-Prediction/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /home/jvgmacedo/UESB CC/Machine Learning/Projeto/Heart-Failure-Prediction/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...

# %% [markdown]
# #### O que fazer a partir daqui:
# - [X] Criar um modelo novo utilizando os melhores parametros obtidos com o gridsearch
# - [] Avaliar o modelo utilizando: matriz de confusao, acuracia, recall, curva de loss (verificar ponto onde a validacao sobe muito e documentar), curva roc e auc. Organizar em metricas gerais.
# - [ ] Conclusao do trabalho

# %% [markdown]
# ## Treinamento do modelo

# %% [markdown]
# ### Criação de um modelo com os melhores parâmetros conforme o gridSearch.
#
# A partir do gridSearch, obtivemos o resultado:
# Melhores parâmetros: {
#   'batch_size': 15, 'epochs': 10,
#   'model__dropout': 0.3,
#   'model__learningRate': 0.001,
#   'model__loss': 'binary_crossentropy',
#   'model__optimizer': 'rmsprop',
#   'model__qtdNeuroniosDense': 32,
#   'model__qtdNeuroniosLSTM': 128,
#   'model__time_steps': 20}
#
# Melhor F1-score na validação cruzada: 0.8873827553695541

# %%
model_optmized = construirModelo(20, 32, 16, 0.3, 0.001, 'binary_crossentropy', 'rmsprop')
# Out:
# /home/jvgmacedo/UESB CC/Machine Learning/Projeto/Heart-Failure-Prediction/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
modelFitted = model_optmized.fit(
    X_train,
    Y_train, 
    epochs = 10, 
    batch_size = 15,
    validation_split = 0.1,
    verbose = 0
)

Y_predict = model_optmized.predict(X_teste)

Y_predict_class = (Y_predict > 0.5).astype(int)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## Avaliação do Modelo

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_teste, Y_predict_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90        62
#            1       0.90      0.95      0.92        76
#
#     accuracy                           0.91       138
#    macro avg       0.92      0.91      0.91       138
# weighted avg       0.91      0.91      0.91       138

# %% [markdown]
# #### Métricas Gerais

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

acc = accuracy_score(Y_teste, Y_predict_class)
prec = precision_score(Y_teste, Y_predict_class)
rec = recall_score(Y_teste, Y_predict_class)
f1 = f1_score(Y_teste, Y_predict_class)

print(f"Acurácia: {acc*100:.2f}%")
print(f"Precisão: {prec*100:.2f}%")
print(f"Recall: {rec*100:.2f}%")
print(f"F1-score: {f1*100:.2f}%")
# Out:
# Acurácia: 91.30%
# Precisão: 90.00%
# Recall: 94.74%
# F1-score: 92.31%

# %% [markdown]
# ### Matriz de confusão

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_teste, Y_predict_class)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['Sem risco', 'Risco'], yticklabels=['Sem risco', 'Risco'])
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# #### Curva ROC AUC

# %%
from sklearn.metrics import roc_curve, roc_auc_score


fpr, tpr, thresholds = roc_curve(Y_teste, Y_predict)
auc_score = roc_auc_score(Y_teste, Y_predict)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f'AUC = {auc_score:.2f}')
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Positivo Verdadeiro (Recall)')
plt.title('Curva ROC')
plt.legend()
plt.show()

# %% [markdown]
# #### Criando Gráfico da Curva de Loss

# %%
plt.figure(figsize=(10, 6))

plt.plot(modelFitted.history['loss'], label='Loss de Treino', color='blue')

if 'val_loss' in modelFitted.history:
    plt.plot(modelFitted.history['val_loss'], label='Loss de Validação', color='orange')

plt.title('Curva de Loss - LSTM (Keras)')
plt.xlabel('Épocas')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Curva Precisão-Recall

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

precision, recall, thresholds = precision_recall_curve(Y_teste, Y_predict_class)
ap = average_precision_score(Y_teste, Y_predict_class)

plt.figure(figsize=(8,6))
plt.plot(recall, precision, label=f'Precisão Média = {ap:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Curva Precision-Recall')
plt.legend()
plt.show()
